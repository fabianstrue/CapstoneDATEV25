# %% [markdown]
# Integrating all code snipppets to get one script as I lost the overview what is up to date to be honest .. to many
#
# I've run the naming of the clustering (TF-IDF) and the clustering with the answers again after handling the noise because I think we forgot that in the parted script before :)

# %%
# %pip install mistralai
# Out:
# Requirement already satisfied: mistralai in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (1.8.1)
# Requirement already satisfied: eval-type-backport>=0.2.0 in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from mistralai) (0.2.2)
# Requirement already satisfied: httpx>=0.28.1 in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from mistralai) (0.28.1)
# Requirement already satisfied: pydantic>=2.10.3 in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from mistralai) (2.11.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from mistralai) (2.9.0.post0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from mistralai) (0.4.1)
# Requirement already satisfied: anyio in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from httpx>=0.28.1->mistralai) (4.9.0)
# Requirement already satisfied: certifi in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from httpx>=0.28.1->mistralai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from httpx>=0.28.1->mistralai) (1.0.9)
# Requirement already satisfied: idna in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from httpx>=0.28.1->mistralai) (3.10)
# Requirement already satisfied: h11>=0.16 in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.28.1->mistralai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from pydantic>=2.10.3->mistralai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from pydantic>=2.10.3->mistralai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from pydantic>=2.10.3->mistralai) (4.13.2)
# Requirement already satisfied: six>=1.5 in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->mistralai) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages (from anyio->httpx>=0.28.1->mistralai) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports
import re
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sentence_transformers import SentenceTransformer, util
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.manifold import TSNE
import umap
import hdbscan
import random
import torch
import collections
import copy
from time import sleep

# %%
from mistralai import Mistral
api_key = "ujI60UR6Fe5jel48SAtfnMiN5Skxfwhq"
modelAI = "open-mistral-nemo"
client = Mistral(api_key=api_key)

# %% [markdown]
# Load the competency questions for 200 documents and generate clusters with HBDSCAN

# %%
# Load competency questions from file
with open("/Users/jule/Desktop/CapstoneDATEV25/competency_questions_output/competency_questions_200_documents.txt", "r", encoding="utf-8") as f:
    content = f.read()

# Extract questions and sources as pairs
pattern = r'\*\*Frage:\*\*\s*(.+?)\s*\*\*Quelle:\*\*\s*(.+?)(?=\n\d+\.\Z|\n\d+\.|\Z)'
entries = re.findall(pattern, content, re.DOTALL)

# Separate question and source for processing
questions_only = [q.strip() for q, s in entries]
sources_only = [s.strip() for q, s in entries]

# Deduplicate questions (with mapping)
seen = set()
questions, sources = [], []
for q, s in zip(questions_only, sources_only):
    if q not in seen:
        seen.add(q)
        questions.append(q)
        sources.append(s)

print(f"✅ Loaded {len(questions)} questions.")
# Out:
# ✅ Loaded 1709 questions.

# %%
#HDBSACN
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
# Sentence Embedding (SBERT)
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
embeddings = model.encode(questions)

# Dimensionality Reduction (UMAP, optional but good for HDBSCAN & visualization)
umap_reducer = umap.UMAP(n_neighbors=15, n_components=5, metric='cosine', random_state=42)
X_umap = umap_reducer.fit_transform(embeddings)

# HDBSCAN clustering (as in the Ntropy article)
clusterer = hdbscan.HDBSCAN(min_cluster_size=5, min_samples=1, metric='euclidean', prediction_data=True)
labels = clusterer.fit_predict(X_umap)
n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
print(f"📌 Number of clusters found by HDBSCAN: {n_clusters}")
# Evaluation (excluding outliers)
valid_mask = labels != -1
sil_score = silhouette_score(X_umap[valid_mask], labels[valid_mask])
print(f"📈 Silhouette Score (without outliers): {sil_score:.4f}")

# Visualization (t-SNE)
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
X_2d = tsne.fit_transform(X_umap)

plt.figure(figsize=(10, 6))
palette = sns.color_palette('hls', n_clusters)
sns.scatterplot(x=X_2d[:, 0], y=X_2d[:, 1], hue=labels, palette=palette)
plt.title("t-SNE visualization of clustered questions")
plt.show()

# Save basic Cluster 
clustered_cqs = {}
for q, l, e in zip(questions, labels, embeddings):
    entry = {"cq": q, "embedding": e.tolist()}
    clustered_cqs.setdefault(f"Cluster {l}", []).append(entry)

with open("clustered_CQs_with_embeddings_new.json", "w", encoding="utf-8") as f:
    json.dump(clustered_cqs, f, ensure_ascii=False, indent=4)
# Out:
# /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Applications/anaconda3/envs/cq_env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 📌 Number of clusters found by HDBSCAN: 139
# 📈 Silhouette Score (without outliers): 0.5280
# /var/folders/sl/zfdz1rpj7ps92n5jb9tm16080000gn/T/ipykernel_66936/188476800.py:29: UserWarning:
# The palette list has fewer values (139) than needed (140) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(x=X_2d[:, 0], y=X_2d[:, 1], hue=labels, palette=palette)

# %% [markdown]
# Use noise triage to handle noise in clusters
#
# 307/1709 questions were identified as noise

# %%
#Handle noise (triage) 
data = clustered_cqs
noise_cl = data.get("Cluster -1", [])
print(f"Noise CQs: {len(noise_cl)} / {sum(len(v) for v in data.values())} total")

PROMOTE_THRESHOLD = 0.2
REVIEW_THRESHOLD = 0.25

noise_embeddings = np.array([x["embedding"] for x in noise_cl])
core_embeddings = []
core_index_to_cluster = {}
c_idx = 0
for cname, cqs in data.items():
    if cname == "Cluster -1": continue
    for cq in cqs:
        core_embeddings.append(cq["embedding"])
        core_index_to_cluster[c_idx] = cname
        c_idx += 1
core_embeddings = np.array(core_embeddings)

from sklearn.metrics.pairwise import cosine_distances
dist_matrix = cosine_distances(noise_embeddings, core_embeddings)

# Get the minimum distance and index of closest core for each noise CQ
d_min = dist_matrix.min(axis=1)
nearest_idx = dist_matrix.argmin(axis=1)

triaged = {"promote": [], "review": [], "leave": []}
for i, cq in enumerate(noise_cl):
    distance = d_min[i]
    nearest_cluster = core_index_to_cluster[nearest_idx[i]]
    tag = "promote" if distance <= PROMOTE_THRESHOLD else "review" if distance <= REVIEW_THRESHOLD else "leave"
    triaged[tag].append({"cq": cq["cq"], "embedding": cq["embedding"], "d_min": float(distance), "nearest_cluster": nearest_cluster})

with open("noise_triage_new.json", "w", encoding="utf-8") as f:
    json.dump(triaged, f, ensure_ascii=False, indent=2)



#Update clustered data with triaged noise
updated_data = {k: copy.deepcopy(v) for k, v in data.items() if k != "Cluster -1"}

#Add promoted and review noise CQs to their nearest clusters and create a new "Cluster -1" for those that are left
for tag in ["promote", "review"]:
    for item in triaged[tag]:
        item["from_noise"] = tag
        updated_data[item["nearest_cluster"]].append(item)
updated_data["Cluster -1"] = [{**item, "from_noise": "leave"} for item in triaged["leave"]]

ordered_data = dict(sorted(updated_data.items(), key=lambda x: (x[0] != "Cluster -1", int(x[0].split()[-1]) if x[0].startswith("Cluster ") else float('inf'))))

with open("clustered_CQs_with_promoted_and_reviewed_noise_new.json", "w", encoding="utf-8") as f:
    json.dump(ordered_data, f, ensure_ascii=False, indent=2)
 

print(f"Promoted: {len(triaged['promote'])}, Reviewed: {len(triaged['review'])}, Left: {len(triaged['leave'])}")
print(f"✅ Updated clustered data with triaged noise. Total clusters: {len(ordered_data)}")   


#Save noise handled clusters also in readable format
clustered_questions_only = {}

for cluster_name, items in ordered_data.items():
    clustered_questions_only[cluster_name] = [entry["cq"] for entry in items if "cq" in entry]

with open("clustered_questions_only_new.json", "w", encoding="utf-8") as f:
    json.dump(clustered_questions_only, f, ensure_ascii=False, indent=2)

print("✅ Saved readable cluster overview to 'clustered_questions_only_new.json'.")
# Out:
# Noise CQs: 307 / 1709 total
# Promoted: 141, Reviewed: 83, Left: 83
# ✅ Updated clustered data with triaged noise. Total clusters: 140
# ✅ Saved readable cluster overview to 'clustered_questions_only_new.json'.

# %% [markdown]
# Use TF-IDF to label the noise-handled clusters

# %%
#TF_IDF labeling and evaluation
np.random.seed(42)
stopwords_de = ["aber", "alle", "als", "also", "am", "an", "ander", "auch", "auf", "aus", "bei", "bin", "bis", "bist", "da", "dadurch", "daher", "darum", "das", "dass", "dein", "deine", "dem", "den", "der", "des", "dessen", "deshalb", "die", "dies", "dieser", "dieses", "doch", "dort", "du", "durch", "ein", "eine", "einem", "einen", "einer", "eines", "er", "es", "euer", "eure", "für", "hatte", "hatten", "hattest", "hattet", "hier", "hinter", "ich", "ihr", "ihre", "im", "in", "ist", "ja", "jede", "jedem", "jeden", "jeder", "jedes", "jener", "jenes", "jetzt", "kann", "kannst", "können", "könnt", "machen", "mein", "meine", "mit", "muß", "mußt", "musst", "müssen", "müßt", "nach", "nachdem", "nein", "nicht", "nun", "oder", "seid", "sein", "seine", "sich", "sie", "sind", "soll", "sollen", "sollst", "sollt", "sonst", "soweit", "sowie", "und", "unser", "unsere", "unter", "vom", "von", "vor", "wann", "warum", "was", "weiter", "weitere", "wenn", "wer", "werde", "werden", "werdet", "weshalb", "wie", "wieder", "wir", "wird", "wirst", "wo", "woher", "wohin", "zu", "zum", "zur", "über"]
synonym_map = {"vergütung": ["entlohnung", "honorar", "bezahlung"], "kündigung": ["beendigung", "auflösung"], "vertrag": ["vereinbarung"]}

def apply_synonyms(texts, mapping):
    for t_idx in range(len(texts)):
        for target, syns in mapping.items():
            for s in syns:
                texts[t_idx] = texts[t_idx].replace(s, target)
    return texts

all_questions, all_labels = [], []
for cname, cqs in ordered_data.items():
    if cname == "Cluster -1": continue
    for cq in cqs:
        all_questions.append(cq["cq"])
        all_labels.append(cname)

questions_syn = apply_synonyms(list(all_questions), synonym_map)
vectorizer = TfidfVectorizer(stop_words=stopwords_de)
X_tfidf = vectorizer.fit_transform(questions_syn)
feature_names = np.array(vectorizer.get_feature_names_out())

cluster_to_questions = collections.defaultdict(list)
for question, label in zip(questions_syn, all_labels):
    cluster_to_questions[label].append(question)

print("\n\U0001F50E Top TF-IDF Keywords per Cluster:")
for cluster_id, texts in cluster_to_questions.items():
    matrix = vectorizer.transform(texts).mean(axis=0).A1
    top_keywords = feature_names[matrix.argsort()[-7:][::-1]]
    print(f"\n\U0001F4C1 {cluster_id} (n={len(texts)}):\nTop Keywords: {', '.join(top_keywords)}")
# Out:
# 🔎 Top TF-IDF Keywords per Cluster:
#
# 📁 Cluster 0 (n=8):
# Top Keywords: netz, kabelnetzbetreiber, betreibers, anderen, signaldurchleitung, signale, kabelnetzes
#
# 📁 Cluster 1 (n=9):
# Top Keywords: patentnichtigkeitsverfahren, kläger, patentnichtigkeitsklage, patent, rechtsschutzmöglichkeit, angegriffene, argumentieren
#
# 📁 Cluster 2 (n=8):
# Top Keywords: unerlaubter, handlung, thailand, ansprüchen, verjährung, thailändischem, recht
#
# 📁 Cluster 3 (n=10):
# Top Keywords: entschädigung, reise, bemessung, ersatzreise, vereitelt, vereitelter, höhe
#
# 📁 Cluster 4 (n=5):
# Top Keywords: geschäftsbedingungen, allgemeinen, reisende, hat, reisevertrag, reisender, kenntnisnahme
#
# 📁 Cluster 5 (n=8):
# Top Keywords: reisende, reise, ansprüche, reiseveranstalter, reisenden, verjähren, verjährungsfrist
#
# 📁 Cluster 6 (n=9):
# Top Keywords: geräuschemissionen, zumutbarkeitsgrenze, schallschutzstandard, mietwohnung, 906, bestimmen, bestimmung
#
# 📁 Cluster 7 (n=6):
# Top Keywords: abtretungsklausel, transparenz, verständlichkeit, abtretung, erfüllt, welche, sicherzustellen
#
# 📁 Cluster 8 (n=10):
# Top Keywords: befruchtung, künstlichen, künstliche, notwendigkeit, kostenübernahme, private, heilbehandlung
#
# 📁 Cluster 9 (n=8):
# Top Keywords: schönheitsreparaturen, fristen, mieter, mietvertrag, abweichen, geltung, vereinbarten
#
# 📁 Cluster 10 (n=7):
# Top Keywords: eisenbahninfrastrukturunternehmen, eisenbahnverkehrsunternehmen, haftpflg, verkehrssicherungspflicht, haftet, abs, bestandsschutz
#
# 📁 Cluster 11 (n=28):
# Top Keywords: abs, mietvertrages, bgb, rechtsgrundlage, gilt, welche, erstattung
#
# 📁 Cluster 12 (n=7):
# Top Keywords: stammkapitalerhöhung, gesellschaften, kreditwürdigkeit, spielt, rolle, welche, kapitalaufbringung
#
# 📁 Cluster 13 (n=22):
# Top Keywords: arztes, arzt, rechnung, goä, leistungen, wahlleistungsvertrag, welche
#
# 📁 Cluster 14 (n=11):
# Top Keywords: wohnungseigentümergemeinschaft, verwaltung, regelung, ordnungsmäßige, beschlussfassung, sonderumlage, immobiliengesellschaft
#
# 📁 Cluster 15 (n=8):
# Top Keywords: abnahme, gemeinschaftlichen, eigentums, gemeinschaftseigentums, gebrauch, erklären, wirksam
#
# 📁 Cluster 16 (n=9):
# Top Keywords: berufungsinstanz, zurückverweisung, aufhebung, welche, rechtsgrundlage, berufungsurteil, gilt
#
# 📁 Cluster 17 (n=13):
# Top Keywords: berufungsgericht, berufungsurteil, revisionsverfahren, überprüfung, angefochtenen, feststellungen, tatsächlichen
#
# 📁 Cluster 18 (n=5):
# Top Keywords: hpflg, satz, abs, anlage, ordnungsmäßiger, haftungsvorschriften, intention
#
# 📁 Cluster 19 (n=11):
# Top Keywords: verpflichtet, mieter, betriebskostenabrechnung, miete, billigem, mangelbeseitigung, neu
#
# 📁 Cluster 20 (n=7):
# Top Keywords: satirischen, kontext, äußerung, satirefreiheit, schutz, unrichtige, erfolgt
#
# 📁 Cluster 21 (n=14):
# Top Keywords: grundstücks, benutzung, wesentliche, 906, grundstück, nutzung, emittierenden
#
# 📁 Cluster 22 (n=28):
# Top Keywords: grundstück, eigentümer, grundstücks, überbau, rechte, welche, hat
#
# 📁 Cluster 23 (n=5):
# Top Keywords: kündigung, außerordentliche, mietverhältnisses, wirksam, damit, lange, auszusprechen
#
# 📁 Cluster 24 (n=5):
# Top Keywords: klageschrift, anschriften, ladungsfähigen, weiteres, übrigen, wohnungseigentümer, ohne
#
# 📁 Cluster 25 (n=6):
# Top Keywords: wasserversorgungsunternehmen, baukostenzuschuss, anschlusses, altleitung, verlangen, erneuerung, vorhaltung
#
# 📁 Cluster 26 (n=6):
# Top Keywords: hoai, honorarvertrag, auftragserteilung, schriftlich, vereinbarung, abs, honoraren
#
# 📁 Cluster 27 (n=18):
# Top Keywords: mietobjekts, gebrauchstauglichkeit, mietverhältnis, mietwohnung, welche, mietfläche, beschreibung
#
# 📁 Cluster 28 (n=6):
# Top Keywords: rechtzeitig, mietsache, zurückgibt, mieter, mietverhältnisses, beendigung, vermieter
#
# 📁 Cluster 29 (n=6):
# Top Keywords: nutzungsentschädigung, rückgabe, mietsache, verspäteter, mietverhältnisses, renoviert, grundlegend
#
# 📁 Cluster 30 (n=16):
# Top Keywords: 89b, hgb, handelsvertreterausgleichs, berechnung, vertragshändler, analog, stammkundenanteil
#
# 📁 Cluster 31 (n=11):
# Top Keywords: mietvertrag, gültigkeit, planunterlagen, mietvertrages, vereinbarung, welche, bedeutung
#
# 📁 Cluster 32 (n=7):
# Top Keywords: gütern, frachtführer, voraussetzungen, damit, erfüllt, transportierten, wert
#
# 📁 Cluster 33 (n=26):
# Top Keywords: mieterhöhungsverlangens, mieterhöhungsverlangen, sachverständigengutachten, begründung, 558, modernisierungsmaßnahmen, welche
#
# 📁 Cluster 34 (n=29):
# Top Keywords: vermieter, mieter, miete, hat, welche, pflichten, wohnung
#
# 📁 Cluster 35 (n=8):
# Top Keywords: mietvertrag, mieterin, welche, rechte, hat, vermieter, optionsrechts
#
# 📁 Cluster 36 (n=8):
# Top Keywords: mietvertrag, verlängerungsklausel, regulären, ablauf, mietzeit, mieterin, voraussetzungen
#
# 📁 Cluster 37 (n=7):
# Top Keywords: erlaubnis, untervermietung, vermieterin, widerrufen, welchen, fehlen, center
#
# 📁 Cluster 38 (n=7):
# Top Keywords: vermieters, makler, provisionsanspruch, namen, vermieter, vermieterin, schwerwiegende
#
# 📁 Cluster 39 (n=10):
# Top Keywords: innengesellschaft, unterbeteiligung, schenkung, vollzogen, gesellschaftsvertrages, abschluss, minderjährigen
#
# 📁 Cluster 40 (n=6):
# Top Keywords: zustimmung, mehrheitsklausel, gesellschafterversammlung, anteilsübertragung, gesellschaftsvertrag, auszulegen, hinblick
#
# 📁 Cluster 41 (n=10):
# Top Keywords: verbandsstrafe, mitglied, satzung, genossenschaft, verhängung, rechtsfolgen, 12
#
# 📁 Cluster 42 (n=19):
# Top Keywords: architekten, architekt, honorarforderung, vergleich, welche, wichtigem, architektentätigkeit
#
# 📁 Cluster 43 (n=22):
# Top Keywords: fahrzeug, umsatzsteuer, schadensersatzleistung, schadensersatz, personen, betreiber, verlangt
#
# 📁 Cluster 44 (n=5):
# Top Keywords: 15a, egzpo, verstehen, begriff, wortlaut, vorschrift, obligatorisch
#
# 📁 Cluster 45 (n=10):
# Top Keywords: richtlinie, nr, art, bestimmungen, anwendung, bedingungen, sachverhalt
#
# 📁 Cluster 46 (n=7):
# Top Keywords: vglo, 104, verstehen, begriff, sinne, bereicherung, aub
#
# 📁 Cluster 47 (n=11):
# Top Keywords: treu, glauben, geltend, auskunftsanspruch, um, verpflichteter, rechte
#
# 📁 Cluster 48 (n=7):
# Top Keywords: frachtführer, standgeld, anspruch, umständen, verpflichtet, zahlung, hoheitlichen
#
# 📁 Cluster 49 (n=9):
# Top Keywords: auflassung, grundbuch, rück, eigentümer, verlangen, eingetragener, vermögensbetreuungspflicht
#
# 📁 Cluster 50 (n=9):
# Top Keywords: leasinggeber, maschinen, leasingvertrag, leasingnehmer, unwirksamkeit, kaution, geschäftssitz
#
# 📁 Cluster 51 (n=7):
# Top Keywords: auftragnehmer, aufstellung, entstandenen, mehrkosten, zuzusenden, verpflichtung, pauschalpreis
#
# 📁 Cluster 52 (n=7):
# Top Keywords: gbr, vertreten, bürgerlichen, rechts, gesellschaft, vertretungsmangel, vertretung
#
# 📁 Cluster 53 (n=11):
# Top Keywords: verpflichtet, tragen, kosten, ersetzen, mängeln, wurde, garantiefalls
#
# 📁 Cluster 54 (n=9):
# Top Keywords: inhabers, 25, früheren, firmenfortführung, verbindlichkeiten, hgb, haftung
#
# 📁 Cluster 55 (n=13):
# Top Keywords: betriebskostenabrechnung, bauantrag, baukostenobergrenze, heizkostenabrechnung, welche, umlagefähige, kostenbestandteile
#
# 📁 Cluster 56 (n=17):
# Top Keywords: kündigung, vob, ganzes, welche, rechtsfolge, tritt, vereinbart
#
# 📁 Cluster 57 (n=8):
# Top Keywords: öffentlich, lageplan, vermessungsingenieur, aufgaben, bestellten, bauprüfvo, nrw
#
# 📁 Cluster 58 (n=13):
# Top Keywords: anlage, elektrizität, wirkungen, schaden, bauausführung, verpflichtet, zurückzuführen
#
# 📁 Cluster 59 (n=9):
# Top Keywords: gemeinschuldnerin, hauptschuldner, gläubigers, rechtsverhältnis, urkunden, rahmen, schuldner
#
# 📁 Cluster 60 (n=17):
# Top Keywords: rückstellung, überschussverteilung, überschussbeteiligung, verwendung, höhe, bonuspunkten, zuteilung
#
# 📁 Cluster 61 (n=10):
# Top Keywords: 906, satz, entsprechend, abs, ausgleichsanspruch, bgb, nachbarrechtlichen
#
# 📁 Cluster 62 (n=13):
# Top Keywords: berichterstattung, person, allgemeinen, persönlichkeitsrechts, informationsinteresse, persönlichkeitsrecht, schutzbedürftiger
#
# 📁 Cluster 63 (n=11):
# Top Keywords: bonuspunkten, zuteilung, anspruch, versicherter, bonuspunkte, versicherten, überschussbeteiligung
#
# 📁 Cluster 64 (n=16):
# Top Keywords: werklohnforderung, ersatz, aufrechnung, anspruch, mängelbeseitigungskosten, vergütung, besteller
#
# 📁 Cluster 65 (n=15):
# Top Keywords: damit, erfüllt, einlageverbindlichkeit, welche, pflichtteilsanspruch, anforderungen, abgetreten
#
# 📁 Cluster 66 (n=7):
# Top Keywords: klage, unbegründet, klageschrift, heilung, tritt, rechtsfolge, kündigungsfolgeschadens
#
# 📁 Cluster 67 (n=11):
# Top Keywords: mitverschulden, darlehensnehmers, berechnet, verschuldens, spielt, rolle, schuldner
#
# 📁 Cluster 68 (n=20):
# Top Keywords: bank, dritten, beratungsfehlern, darlehensnehmer, zurechnung, aufklärungspflicht, beratungsfehler
#
# 📁 Cluster 69 (n=13):
# Top Keywords: abs, zpo, sinne, nr, rechtsverhältnisses, bestehens, 256
#
# 📁 Cluster 70 (n=8):
# Top Keywords: zvg, 57a, abs, sonderkündigungsrecht, 73, betravg, übergangsregelungen
#
# 📁 Cluster 71 (n=5):
# Top Keywords: annullierung, ausgeübt, vorschrift, luftfahrtunternehmens, absicht, flugs, verordnung
#
# 📁 Cluster 72 (n=9):
# Top Keywords: widerrufsrecht, widerrufsbelehrung, fernabsatzvertrag, widerrufsrechts, enthält, vertragliches, bestimmungen
#
# 📁 Cluster 73 (n=6):
# Top Keywords: 281, fristsetzung, abs, bgb, sinne, frist, begriff
#
# 📁 Cluster 74 (n=16):
# Top Keywords: hat, kunde, welche, gewinnabführungsvertrages, beherrschungs, rechte, geleistet
#
# 📁 Cluster 75 (n=5):
# Top Keywords: anleger, aktien, verkauf, aufklärung, sittenwidrige, schädigung, zusammenhang
#
# 📁 Cluster 76 (n=34):
# Top Keywords: bgb, 823, haftung, abs, 826, welche, 249
#
# 📁 Cluster 77 (n=6):
# Top Keywords: schadensersatzanspruchs, fondsanteilen, haben, mandant, rechtsberatung, übertragung, notwendige
#
# 📁 Cluster 78 (n=13):
# Top Keywords: sachverständigenkosten, kostenbeteiligung, heimaufenthalt, beklagten, haftung, quotenmäßigen, welche
#
# 📁 Cluster 79 (n=6):
# Top Keywords: datei, uniwagnis, versicherer, daten, versicherungsnehmers, sicherstellen, informationen
#
# 📁 Cluster 80 (n=22):
# Top Keywords: aufklärungsobliegenheit, versicherungsnehmer, auskunfts, verletzt, rechtsfolgen, welche, leistungsfreiheit
#
# 📁 Cluster 81 (n=7):
# Top Keywords: pauschalpreisvertrag, vorzeitig, abrechnung, pauschalpreisvertrages, beendeten, gilt, gekündigten
#
# 📁 Cluster 82 (n=10):
# Top Keywords: vergütung, mindestvergütung, berechnen, auszahlung, erhöhten, beendeten, vorzeitig
#
# 📁 Cluster 83 (n=20):
# Top Keywords: vergütung, werkvertrags, 631, übliche, rahmen, bgb, keine
#
# 📁 Cluster 84 (n=10):
# Top Keywords: geschäftsführers, gmbh, kündigung, geschäftsführer, ordentliche, welche, rechte
#
# 📁 Cluster 85 (n=8):
# Top Keywords: zahlen, einmalprämie, zahlung, vertragsschluss, verpflichtet, vertrag, leistungsumfangs
#
# 📁 Cluster 86 (n=9):
# Top Keywords: unwirksam, wartungspflicht, garantie, verschmelzung, zeitpunkt, wegen, verletzung
#
# 📁 Cluster 87 (n=9):
# Top Keywords: versicherungsnehmers, versicherungsmaklers, enteignungsangelegenheiten, beratungspflicht, auslegung, begriff, welche
#
# 📁 Cluster 88 (n=11):
# Top Keywords: subsidiaritätsklauseln, mehrfachversicherungen, versicherungsbedingungen, versicherern, innenausgleich, versicherung, welche
#
# 📁 Cluster 89 (n=12):
# Top Keywords: finanzierung, einlageverbindlichkeit, feststellung, rechnung, verwirkt, zusammenhang, rückzahlungsanspruch
#
# 📁 Cluster 90 (n=5):
# Top Keywords: prospektmangel, ursächlich, anlageentscheidung, entnommen, liquidität, anlageberatung, unabhängige
#
# 📁 Cluster 91 (n=7):
# Top Keywords: hinauskündigungsklausel, gmbh, vereinbart, wirksam, abfindung, vereinbaren, gesellschaftsrechtlichen
#
# 📁 Cluster 92 (n=13):
# Top Keywords: bgb, vorliegt, 666, 677, damit, erfüllt, werkvertrag
#
# 📁 Cluster 93 (n=6):
# Top Keywords: verhandlungen, verjährung, bausumme, toleranzrahmens, täuschungshandlung, differenzschaden, bedeutung
#
# 📁 Cluster 94 (n=11):
# Top Keywords: unternehmer, berücksichtigen, beispiel, werkes, geltend, besteller, hat
#
# 📁 Cluster 95 (n=8):
# Top Keywords: gmbh, gesellschafter, persönlich, prodhaftg, haften, unternehmen, welche
#
# 📁 Cluster 96 (n=7):
# Top Keywords: kunde, bgb, 323, gebrauch, seinem, damit, erfüllt
#
# 📁 Cluster 97 (n=10):
# Top Keywords: anordnung, gericht, ausländische, welche, auslandszustellung, förmlichen, zuständigkeit
#
# 📁 Cluster 98 (n=8):
# Top Keywords: versicherungsnehmer, versicherer, obliegenheit, versicherungsnehmers, mangelnder, beratung, welchen
#
# 📁 Cluster 99 (n=8):
# Top Keywords: arbeitsunfähigkeit, tätigkeitsfeld, selbständiger, wechselt, berufliches, weiterhin, versicherungspflichtig
#
# 📁 Cluster 100 (n=9):
# Top Keywords: verkäufer, vertragshändler, informationspflichten, rahmen, vertriebshändler, weiterer, einsetzung
#
# 📁 Cluster 101 (n=18):
# Top Keywords: geschäftsbedingungen, allgemeinen, klausel, klauseln, welche, auftrag, geprüft
#
# 📁 Cluster 102 (n=7):
# Top Keywords: unternehmen, geschäftstätigkeit, kunden, erweitern, ordnungsgemäßen, pflichtenkreis, beratung
#
# 📁 Cluster 103 (n=12):
# Top Keywords: verjährungsfrist, bgb, 666, 477, auskunftsanspruch, beweisverfahren, lange
#
# 📁 Cluster 104 (n=27):
# Top Keywords: bgb, voraussetzungen, welche, anfechtung, 229, egbgb, 439
#
# 📁 Cluster 105 (n=14):
# Top Keywords: partei, prozessunfähige, vertreten, ordnungsgemäß, ausgleichsanspruchs, geltendmachung, wurde
#
# 📁 Cluster 106 (n=23):
# Top Keywords: partei, gericht, welche, hat, prozessfähigkeit, verfahren, parteien
#
# 📁 Cluster 107 (n=9):
# Top Keywords: revision, urteil, welche, verhandlung, urteilsverkündung, unzulässigkeit, entscheidung
#
# 📁 Cluster 108 (n=11):
# Top Keywords: gesundheitsbeeinträchtigung, kausalität, unfallereignis, beurteilung, zwischen, unfallereignisses, privaten
#
# 📁 Cluster 109 (n=6):
# Top Keywords: person, ob, arbeitsunfall, somit, verursacht, verletzt, pflichten
#
# 📁 Cluster 110 (n=9):
# Top Keywords: geschäftsführervertrag, geschäftsführervertrages, unwirksam, wirksamkeit, abfindungsklausel, geschäftsführerposition, bestätigen
#
# 📁 Cluster 111 (n=12):
# Top Keywords: gmbh, komplementär, kommanditgesellschaft, geschäftsführer, gegenüber, geschäftsführers, geschäfte
#
# 📁 Cluster 112 (n=9):
# Top Keywords: sachverständigenkosten, schadensersatzrecht, quotierung, spielt, rolle, welche, haftpflichtversicherung
#
# 📁 Cluster 113 (n=15):
# Top Keywords: partei, vertrag, honorarvertrag, geschäftsunfähigkeit, bedingung, agbg, welche
#
# 📁 Cluster 114 (n=15):
# Top Keywords: bgb, vertrages, 539, bedeutung, nichtig, abs, 138
#
# 📁 Cluster 115 (n=11):
# Top Keywords: werkleistung, mangelhafter, konkrete, geschädigte, schaden, schadensabrechnung, berechnung
#
# 📁 Cluster 116 (n=34):
# Top Keywords: schadensersatzanspruch, welche, verletzung, schadensersatzanspruchs, hat, verjährung, gemacht
#
# 📁 Cluster 117 (n=7):
# Top Keywords: bgb, partei, vertrag, wille, rechtsfolge, tritt, vertragsparteien
#
# 📁 Cluster 118 (n=11):
# Top Keywords: handlung, ansprüchen, gilt, geltendmachung, rechtsgrundlage, unerlaubten, feststellungswiderklage
#
# 📁 Cluster 119 (n=25):
# Top Keywords: klage, schlichtungsverfahren, klageerhebung, welche, verpflichtet, voraussetzungen, schlichtungsversuch
#
# 📁 Cluster 120 (n=22):
# Top Keywords: verjährungsfrist, zustellung, frist, annullierung, rechtsfolge, tritt, verzögert
#
# 📁 Cluster 121 (n=14):
# Top Keywords: schadensersatzanspruch, käufer, bestellers, mangels, geltend, verkäufer, schadensersatzansprüchen
#
# 📁 Cluster 122 (n=8):
# Top Keywords: lebenszeit, erprobung, richter, richters, abgeordnet, richtern, unterziehen
#
# 📁 Cluster 123 (n=15):
# Top Keywords: bedeutung, welche, hat, spielt, rolle, prospektfehlers, aussagegehalts
#
# 📁 Cluster 124 (n=10):
# Top Keywords: vertragspartner, provisionsanspruchs, anschrift, spielt, rolle, geltendmachung, voraussetzungen
#
# 📁 Cluster 125 (n=16):
# Top Keywords: auswirkungen, welche, zustellung, einspruchsfrist, spielt, rolle, hat
#
# 📁 Cluster 126 (n=15):
# Top Keywords: damit, erfüllt, prozessvergleichs, prozessvergleich, welche, voraussetzungen, widerruf
#
# 📁 Cluster 127 (n=8):
# Top Keywords: kaufsache, mangelhafte, zurückweist, käufer, verkäufer, zurückweisen, liefert
#
# 📁 Cluster 128 (n=8):
# Top Keywords: vertrag, bedeutung, regelung, vertragsangebots, eigenhaftung, greift, ob
#
# 📁 Cluster 129 (n=7):
# Top Keywords: änderungsvertrags, schriftform, interpretation, bedeutung, hat, welche, pachtvertrags
#
# 📁 Cluster 130 (n=8):
# Top Keywords: vertragsparteien, verpflichtungen, bedeutung, vertrages, gesellschaft, welche, auslegung
#
# 📁 Cluster 131 (n=20):
# Top Keywords: käufer, verkäufer, verkäufers, veränderungssperre, arglistig, kaufsache, aufgrund
#
# 📁 Cluster 132 (n=27):
# Top Keywords: käufer, vorkaufsrecht, sondereigentum, welche, widerrufsrecht, erbanteils, rechte
#
# 📁 Cluster 133 (n=20):
# Top Keywords: frachtführers, abschrift, welche, rechtsgrundlage, gilt, klageschrift, haftung
#
# 📁 Cluster 134 (n=8):
# Top Keywords: unzulässig, notar, vollmacht, erklärt, auflassung, widerwiderklage, antrages
#
# 📁 Cluster 135 (n=7):
# Top Keywords: kläger, stammt, strohmann, klägerin, beklagte, unternehmens, beklagten
#
# 📁 Cluster 136 (n=15):
# Top Keywords: klägerin, beklagten, verhalten, beklagte, anspruch, kläger, gegenüber
#
# 📁 Cluster 137 (n=10):
# Top Keywords: feststellungswiderklage, rechtskraft, gericht, hat, entscheidung, bedeutung, nichtigkeitsklage
#
# 📁 Cluster 138 (n=21):
# Top Keywords: urteils, gericht, klage, rechtskraft, welche, hat, entscheidung

# %% [markdown]
# Generate generalized questions for the noise reduced clusters

# %%
#GCQs
results = {}

system_prompt = """
You are a legal knowledge engineering expert.

Your task is to generate a **generalized competency question (GCQ)** from a list of **clustered German legal competency questions (CQs)**.

---

## Goal:
Create **one single abstract, representative legal question** that captures the core meaning of all input CQs.

## Instructions:
- Output one well-formed, precise, **legally relevant** question in German.
- The question should reflect the **shared semantics** of the cluster without copying specific details.
- Use **legal terminology** such as:
  - “Unter welchen Voraussetzungen…”
  - “Welche rechtliche Bedeutung hat…”
  - “Wer ist verpflichtet…”
- Do not summarize, explain, or list individual CQs. Just output the **generalized question**.
- Output **only the question**, in natural, legal German.

---

## Examples:

### Cluster Example 1:
Input:
- Welche Rechtsgrundlage gilt für die Präklusion einer Aufrechnung aufgrund von Verspätung?
- Welche Rechtsgrundlage gilt für die Zurechnung von Handlungen des Auslieferungsfahrers auf den Frachtführer?
- Welche Rechtsgrundlage gilt für die Haftung bei grob fahrlässig herbeigeführten Arbeitsunfällen?
- Welche Rechtsgrundlage gilt für den Nachweis von grober Fahrlässigkeit bei Arbeitsunfällen?
- Welche Rechtsgrundlage gilt für die Haftung eines Dritten, der ohne Verschulden an einem Schaden beteiligt ist?
- Welche Rechtsgrundlage gilt für die Haftung eines Unternehmens bei Verletzung von Datenschutzbestimmungen?
- Wie ist die Zurechnung von Beratungsfehlern eines Dritten auf einen Verkäufer im Rahmen von Schadensersatzansprüchen zu beurteilen?
- Welche Rechtsgrundlage gilt für die Zurechnung von Beratungsfehlern eines Dritten auf eine Bank?
- Welche Rechtsgrundlage gilt für die Zurechnung von Schäden, die durch den Rücktritt vom Kaufvertrag entstehen?
- Welche Bedeutung hat die Verletzung oder Tötung des Inhabers oder Mitarbeiters eines Unternehmens für den Gewerbebetrieb?
- Welche Rechtsgrundlage gilt für den Ersatz eines Schadens, der auf den Verlust eines Leibgedings zurückzuführen ist?
- Welche Rolle spielt das institutionalisierte Zusammenwirken bei der Zurechnung von Beratungsfehlern?

GCQ:
Unter welchen Voraussetzungen wird ein Verhalten rechtlich einer anderen Person oder Stelle zugerechnet?

---

### Cluster Example 2:
Input:
- Welche Voraussetzungen müssen erfüllt sein, damit Versicherte einen Anspruch auf Überschussbeteiligung durch die Beklagte haben?
- Wie wird die Höhe der Überschussbeteiligung durch die Beklagte bestimmt?
- Welche Rechte haben die Versicherten, wenn die Beklagte den satzungsgemäßen Vorgaben für die Überschussbeteiligung nicht nachkommt?
- Welche Rechtsgrundlage gilt für den Anspruch der Versicherten auf Überschussbeteiligung entsprechend den satzungsgemäßen Vorgaben?
- Welche Rechtsfolge tritt ein, wenn die Beklagte den satzungsgemäßen Vorgaben für die Überschussbeteiligung nicht nachkommt und die Versicherten keine gerichtliche Feststellung begehren?
- Welche Umstände können die Höhe der Entschädigung beeinflussen?

GCQ:
Wann entsteht ein Anspruch auf eine Beteiligung an Überschüssen aus einem Versicherungsverhältnis?

---

### Cluster Example 3:
Input:
- Welche Voraussetzungen müssen erfüllt sein, damit ein Käufer nach § 437 Nr. 3 BGB Schadensersatz für einen mangelbedingten Nutzungsausfall verlangen kann, auch wenn er vom Kaufvertrag zurückgetreten ist?
- Wer ist verpflichtet, Wertersatz für die Nutzung einer Kaufsache zu zahlen, wenn der Käufer vom Kaufvertrag zurücktritt?
- Wie ist der Schadensersatzanspruch des Käufers nach § 437 Nr. 3 BGB im Falle eines Rücktritts vom Kaufvertrag zu berechnen?
- Welche Rolle spielt der § 325 BGB bei der Geltendmachung eines Schadensersatzanspruchs durch den Käufer nach einem Rücktritt vom Kaufvertrag?
- Wie ist der Schadensersatzanspruch des Käufers nach § 437 Nr. 3 BGB zu berechnen, wenn der Käufer die Reparaturkosten für das mangelhafte Fahrzeug nicht selbst tragen muss?
- Welche Bedingungen müssen erfüllt sein, damit der Käufer nach § 437 Nr. 3 BGB Schadensersatz für einen mangelbedingten Nutzungsausfall verlangen kann?
- Welche Rechte hat der Käufer, der aufgrund eines Mangels vom Kaufvertrag zurücktritt und Schadensersatz nach § 437 Nr. 3 BGB beansprucht?
- Wie ist der Schadensersatzanspruch des Käufers nach § 437 Nr. 3 BGB im Falle eines Rücktritts vom Kaufvertrag und einer Herausgabe der mangelhaften Kaufsache zu berechnen?

GCQ:
Unter welchen Bedingungen bleibt ein Anspruch auf Schadensersatz bestehen, wenn ein Vertragsverhältnis rückabgewickelt wird?

"""


for cluster_id, questions in ordered_data.items():
    prompt = system_prompt + "\n\nFragen:\n" + "\n".join(f"- {q['cq']}" for q in questions if 'cq' in q) + "\n\nGeneralisierte Frage:"
    try:
        response = client.chat.complete(
            model=modelAI,
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": prompt}
            ]
        )
        results[cluster_id] = response.choices[0].message.content.strip()
    except Exception as e:
        print(f"Fehler bei Cluster {cluster_id}:", e)
        results[cluster_id] = "Error generating question."
    sleep(3)

with open("generalized_questions_new.json", "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

print("Fertig – generalisierte Fragen wurden gespeichert.")
# Out:
# Fertig – generalisierte Fragen wurden gespeichert.

# %% [markdown]
# Include the sources for each question

# %%
#Load the original CQ-to-source mappings
import re
import json


cq_source_map = {}

with open("/Users/jule/Desktop/CapstoneDATEV25/competency_questions_output/competency_questions_200_documents.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

# Match Frage + Quelle pairs
pattern = r'\*\*Frage:\*\*\s*(.+?)\s*\*\*Quelle:\*\*\s*(.+?)(?=\n\d+\.|\Z)'
matches = re.findall(pattern, raw_text, re.DOTALL)

for question, source in matches:
    cleaned_q = question.strip()
    cleaned_source = source.strip().strip('"').strip()
    cq_source_map[cleaned_q] = cleaned_source

print(f"✅ Extracted {len(cq_source_map)} CQ-to-source pairs.")
# === Step 2: Load clustered data ===

with open("clustered_CQs_with_promoted_and_reviewed_noise_new.json", "r", encoding="utf-8") as f:
    clustered_data = json.load(f)

# === Step 3: Map CQs in clusters to their original sources ===

clustered_with_sources = {}

missing_sources = []

for cluster_name, cqs in clustered_data.items():
    cluster_entries = []
    for cq_entry in cqs:
        question = cq_entry.get("cq", "").strip()
        source = cq_source_map.get(question)
        if not source:
            missing_sources.append(question)
            source = "UNKNOWN"  # Fallback
        cluster_entries.append({
            "cq": question,
            "quelle": source
        })
    clustered_with_sources[cluster_name] = cluster_entries

# === Step 4: Save to JSON ===

with open("clustered_CQs_with_sources.json", "w", encoding="utf-8") as f:
    json.dump(clustered_with_sources, f, ensure_ascii=False, indent=2)

print(f"✅ Saved clustered questions with sources to 'clustered_CQs_with_sources.json'.")
if missing_sources:
    print(f"⚠️ {len(missing_sources)} questions had no matching source.")
    with open("missing_sources_log.txt", "w", encoding="utf-8") as f:
        for q in missing_sources:
            f.write(q + "\n")
    print("⚠️ Missing questions logged in 'missing_sources_log.txt'.")
# Out:
# ✅ Extracted 1709 CQ-to-source pairs.

# %%
# Load clustered data

with open("clustered_CQs_with_promoted_and_reviewed_noise_new.json", "r", encoding="utf-8") as f:
    clustered_data = json.load(f)

# Map CQs in clusters to their original sources 

clustered_with_sources = {}

missing_sources = []

for cluster_name, cqs in clustered_data.items():
    cluster_entries = []
    for cq_entry in cqs:
        question = cq_entry.get("cq", "").strip()
        source = cq_source_map.get(question)
        if not source:
            missing_sources.append(question)
            source = "UNKNOWN"  # Fallback
        cluster_entries.append({
            "cq": question,
            "quelle": source
        })
    clustered_with_sources[cluster_name] = cluster_entries

#Save to JSON

with open("clustered_CQs_with_sources.json", "w", encoding="utf-8") as f:
    json.dump(clustered_with_sources, f, ensure_ascii=False, indent=2)

print(f"✅ Saved clustered questions with sources to 'clustered_CQs_with_sources.json'.")
if missing_sources:
    print(f"⚠️ {len(missing_sources)} questions had no matching source.")
    with open("missing_sources_log.txt", "w", encoding="utf-8") as f:
        for q in missing_sources:
            f.write(q + "\n")
    print("⚠️ Missing questions logged in 'missing_sources_log.txt'.")
# Out:
# ✅ Saved clustered questions with sources to 'clustered_CQs_with_sources.json'.
